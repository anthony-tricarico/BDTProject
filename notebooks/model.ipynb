# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/generated/stop_times_passengers_5days.csv')

# %%
for _, x in df.iterrows():
    print(x)
# Out:
# Unnamed: 0                                  0
# stop_id                                  3049
# route_short_name                           L1
# arrival_time                         06:32:00
# departure_time                       06:32:00
# trip_id             0004187192024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              7
# Name: 0, dtype: object
# Unnamed: 0                                  1
# stop_id                                  3050
# route_short_name                           L1
# arrival_time                         06:32:00
# departure_time                       06:32:00
# trip_id             0004187192024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                  4
# passengers_out                              2
# Name: 1, dtype: object
# Unnamed: 0                                  2
# stop_id                                  3052
# route_short_name                           L1
# arrival_time                         06:33:00
# departure_time                       06:33:00
# trip_id             0004187192024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              1
# Name: 2, dtype: object
# Unnamed: 0                                  3
# stop_id                                  3054
# route_short_name                           L1
# arrival_time                         06:34:00
# departure_time                       06:34:00
# trip_id             0004187192024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                  7
# passengers_out                              4
# Name: 3, dtype: object
# Unnamed: 0                                  4
# stop_id                                  3047
# route_short_name                           L1
# arrival_time                         06:35:00
# departure_time                       06:35:00
# trip_id             0004187192024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                  8
# passengers_out                              5
# Name: 4, dtype: object
# Unnamed: 0                                  5
# stop_id                                  3014
# route_short_name                           L1
# arrival_time                         15:49:00
# departure_time                       15:49:00
# trip_id             0004187202024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              1
# Name: 5, dtype: object
# Unnamed: 0                                  6
# stop_id                                  3016
# route_short_name                           L1
# arrival_time                         15:50:00
# departure_time                       15:50:00
# trip_id             0004187202024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                  5
# passengers_out                              2
# Name: 6, dtype: object
# Unnamed: 0                                  7
# stop_id                                  3017
# route_short_name                           L1
# arrival_time                         15:51:00
# departure_time                       15:51:00
# trip_id             0004187202024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              2
# Name: 7, dtype: object
# Unnamed: 0                                  8
# stop_id                                  3018
# route_short_name                           L1
# arrival_time                         15:52:00
# departure_time                       15:52:00
# trip_id             0004187202024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 15
# passengers_out                              4
# Name: 8, dtype: object
# Unnamed: 0                                  9
# stop_id                                  3019
# route_short_name                           L1
# arrival_time                         15:54:00
# departure_time                       15:54:00
# trip_id             0004187202024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              4
# Name: 9, dtype: object
# Unnamed: 0                                 10
# stop_id                                  3079
# route_short_name                           L1
# arrival_time                         15:55:00
# departure_time                       15:55:00
# trip_id             0004187202024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              5
# Name: 10, dtype: object
# Unnamed: 0                                 11
# stop_id                                  3040
# route_short_name                           L1
# arrival_time                         15:57:00
# departure_time                       15:57:00
# trip_id             0004187202024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                  7
# passengers_out                              1
# Name: 11, dtype: object
# Unnamed: 0                                 12
# stop_id                                  3073
# route_short_name                           L1
# arrival_time                         15:57:00
# departure_time                       15:57:00
# trip_id             0004187202024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                 26
# passengers_out                              9
# Name: 12, dtype: object
# Unnamed: 0                                 13
# stop_id                                  3074
# route_short_name                           L1
# arrival_time                         15:58:00
# departure_time                       15:58:00
# trip_id             0004187202024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                 10
# passengers_out                              0
# Name: 13, dtype: object
# Unnamed: 0                                 14
# stop_id                                  3037
# route_short_name                           L1
# arrival_time                         16:00:00
# departure_time                       16:00:00
# trip_id             0004187202024090920250601
# stop_sequence                              10
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              5
# Name: 14, dtype: object
# Unnamed: 0                                 15
# stop_id                                  3036
# route_short_name                           L1
# arrival_time                         16:00:00
# departure_time                       16:00:00
# trip_id             0004187202024090920250601
# stop_sequence                              11
# hospital                                    0
# school                                      0
# passengers                                 23
# passengers_out                              6
# Name: 15, dtype: object
# Unnamed: 0                                 16
# stop_id                                  3014
# route_short_name                           L1
# arrival_time                         18:39:00
# departure_time                       18:39:00
# trip_id             0004187212024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              1
# Name: 16, dtype: object
# Unnamed: 0                                 17
# stop_id                                  3016
# route_short_name                           L1
# arrival_time                         18:40:00
# departure_time                       18:40:00
# trip_id             0004187212024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 28
# passengers_out                              8
# Name: 17, dtype: object
# Unnamed: 0                                 18
# stop_id                                  3017
# route_short_name                           L1
# arrival_time                         18:41:00
# departure_time                       18:41:00
# trip_id             0004187212024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              4
# Name: 18, dtype: object
# Unnamed: 0                                 19
# stop_id                                  3018
# route_short_name                           L1
# arrival_time                         18:42:00
# departure_time                       18:42:00
# trip_id             0004187212024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              2
# Name: 19, dtype: object
# Unnamed: 0                                 20
# stop_id                                  3019
# route_short_name                           L1
# arrival_time                         18:44:00
# departure_time                       18:44:00
# trip_id             0004187212024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 26
# passengers_out                              6
# Name: 20, dtype: object
# Unnamed: 0                                 21
# stop_id                                  3079
# route_short_name                           L1
# arrival_time                         18:45:00
# departure_time                       18:45:00
# trip_id             0004187212024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              1
# Name: 21, dtype: object
# Unnamed: 0                                 22
# stop_id                                  3040
# route_short_name                           L1
# arrival_time                         18:47:00
# departure_time                       18:47:00
# trip_id             0004187212024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              4
# Name: 22, dtype: object
# Unnamed: 0                                 23
# stop_id                                  3073
# route_short_name                           L1
# arrival_time                         18:47:00
# departure_time                       18:47:00
# trip_id             0004187212024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                 26
# passengers_out                              4
# Name: 23, dtype: object
# Unnamed: 0                                 24
# stop_id                                  3074
# route_short_name                           L1
# arrival_time                         18:48:00
# departure_time                       18:48:00
# trip_id             0004187212024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              6
# Name: 24, dtype: object
# Unnamed: 0                                 25
# stop_id                                  3037
# route_short_name                           L1
# arrival_time                         18:50:00
# departure_time                       18:50:00
# trip_id             0004187212024090920250601
# stop_sequence                              10
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              3
# Name: 25, dtype: object
# Unnamed: 0                                 26
# stop_id                                  3036
# route_short_name                           L1
# arrival_time                         18:50:00
# departure_time                       18:50:00
# trip_id             0004187212024090920250601
# stop_sequence                              11
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              3
# Name: 26, dtype: object
# Unnamed: 0                                 27
# stop_id                                  3014
# route_short_name                           L2
# arrival_time                         14:14:00
# departure_time                       14:14:00
# trip_id             0004187222024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              4
# Name: 27, dtype: object
# Unnamed: 0                                 28
# stop_id                                  3094
# route_short_name                           L2
# arrival_time                         14:15:00
# departure_time                       14:15:00
# trip_id             0004187222024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              5
# Name: 28, dtype: object
# Unnamed: 0                                 29
# stop_id                                  3022
# route_short_name                           L2
# arrival_time                         14:16:00
# departure_time                       14:16:00
# trip_id             0004187222024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              2
# Name: 29, dtype: object
# Unnamed: 0                                 30
# stop_id                                  3037
# route_short_name                           L2
# arrival_time                         14:17:00
# departure_time                       14:17:00
# trip_id             0004187222024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 19
# passengers_out                              6
# Name: 30, dtype: object
# Unnamed: 0                                 31
# stop_id                                  3036
# route_short_name                           L2
# arrival_time                         14:17:00
# departure_time                       14:17:00
# trip_id             0004187222024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                  9
# passengers_out                              2
# Name: 31, dtype: object
# Unnamed: 0                                 32
# stop_id                                  3014
# route_short_name                           L3
# arrival_time                         07:27:00
# departure_time                       07:27:00
# trip_id             0004187232024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              2
# Name: 32, dtype: object
# Unnamed: 0                                 33
# stop_id                                  3094
# route_short_name                           L3
# arrival_time                         07:28:00
# departure_time                       07:28:00
# trip_id             0004187232024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 20
# passengers_out                              7
# Name: 33, dtype: object
# Unnamed: 0                                 34
# stop_id                                  3029
# route_short_name                           L3
# arrival_time                         07:29:00
# departure_time                       07:29:00
# trip_id             0004187232024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 20
# passengers_out                              4
# Name: 34, dtype: object
# Unnamed: 0                                 35
# stop_id                                  3027
# route_short_name                           L3
# arrival_time                         07:30:00
# departure_time                       07:30:00
# trip_id             0004187232024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              5
# Name: 35, dtype: object
# Unnamed: 0                                 36
# stop_id                                  3014
# route_short_name                           L3
# arrival_time                         08:27:00
# departure_time                       08:27:00
# trip_id             0004187242024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              5
# Name: 36, dtype: object
# Unnamed: 0                                 37
# stop_id                                  3094
# route_short_name                           L3
# arrival_time                         08:28:00
# departure_time                       08:28:00
# trip_id             0004187242024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 22
# passengers_out                              8
# Name: 37, dtype: object
# Unnamed: 0                                 38
# stop_id                                  3029
# route_short_name                           L3
# arrival_time                         08:29:00
# departure_time                       08:29:00
# trip_id             0004187242024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              5
# Name: 38, dtype: object
# Unnamed: 0                                 39
# stop_id                                  3027
# route_short_name                           L3
# arrival_time                         08:30:00
# departure_time                       08:30:00
# trip_id             0004187242024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 28
# passengers_out                              8
# Name: 39, dtype: object
# Unnamed: 0                                 40
# stop_id                                  3014
# route_short_name                           L3
# arrival_time                         12:23:00
# departure_time                       12:23:00
# trip_id             0004187252024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 11
# passengers_out                              5
# Name: 40, dtype: object
# Unnamed: 0                                 41
# stop_id                                  3094
# route_short_name                           L3
# arrival_time                         12:00:00
# departure_time                       12:00:00
# trip_id             0004187252024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              4
# Name: 41, dtype: object
# Unnamed: 0                                 42
# stop_id                                  3029
# route_short_name                           L3
# arrival_time                         12:25:00
# departure_time                       12:25:00
# trip_id             0004187252024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                  8
# passengers_out                              1
# Name: 42, dtype: object
# Unnamed: 0                                 43
# stop_id                                  3027
# route_short_name                           L3
# arrival_time                         12:26:00
# departure_time                       12:26:00
# trip_id             0004187252024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 10
# passengers_out                              0
# Name: 43, dtype: object
# Unnamed: 0                                 44
# stop_id                                  3014
# route_short_name                           L3
# arrival_time                         18:23:00
# departure_time                       18:23:00
# trip_id             0004187262024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 15
# passengers_out                              2
# Name: 44, dtype: object
# Unnamed: 0                                 45
# stop_id                                  3094
# route_short_name                           L3
# arrival_time                         18:00:00
# departure_time                       18:00:00
# trip_id             0004187262024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 24
# passengers_out                              8
# Name: 45, dtype: object
# Unnamed: 0                                 46
# stop_id                                  3029
# route_short_name                           L3
# arrival_time                         18:25:00
# departure_time                       18:25:00
# trip_id             0004187262024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              3
# Name: 46, dtype: object
# Unnamed: 0                                 47
# stop_id                                  3027
# route_short_name                           L3
# arrival_time                         18:26:00
# departure_time                       18:26:00
# trip_id             0004187262024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              4
# Name: 47, dtype: object
# Unnamed: 0                                 48
# stop_id                                  3014
# route_short_name                           L4
# arrival_time                         12:03:00
# departure_time                       12:03:00
# trip_id             0004187282024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              7
# Name: 48, dtype: object
# Unnamed: 0                                 49
# stop_id                                  3094
# route_short_name                           L4
# arrival_time                         12:04:00
# departure_time                       12:04:00
# trip_id             0004187282024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                  9
# passengers_out                              6
# Name: 49, dtype: object
# Unnamed: 0                                 50
# stop_id                                  3030
# route_short_name                           L4
# arrival_time                         12:08:00
# departure_time                       12:08:00
# trip_id             0004187282024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              6
# Name: 50, dtype: object
# Unnamed: 0                                 51
# stop_id                                  3031
# route_short_name                           L4
# arrival_time                         12:09:00
# departure_time                       12:09:00
# trip_id             0004187282024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              7
# Name: 51, dtype: object
# Unnamed: 0                                 52
# stop_id                                  3032
# route_short_name                           L4
# arrival_time                         12:10:00
# departure_time                       12:10:00
# trip_id             0004187282024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              7
# Name: 52, dtype: object
# Unnamed: 0                                 53
# stop_id                                  3033
# route_short_name                           L4
# arrival_time                         12:11:00
# departure_time                       12:11:00
# trip_id             0004187282024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                  4
# passengers_out                              2
# Name: 53, dtype: object
# Unnamed: 0                                 54
# stop_id                                  3034
# route_short_name                           L4
# arrival_time                         12:12:00
# departure_time                       12:12:00
# trip_id             0004187282024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                  8
# passengers_out                              5
# Name: 54, dtype: object
# Unnamed: 0                                 55
# stop_id                                  3035
# route_short_name                           L4
# arrival_time                         12:13:00
# departure_time                       12:13:00
# trip_id             0004187282024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                  2
# passengers_out                              0
# Name: 55, dtype: object
# Unnamed: 0                                 56
# stop_id                                  3014
# route_short_name                           L4
# arrival_time                         12:16:00
# departure_time                       12:16:00
# trip_id             0004187282024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                  8
# passengers_out                              3
# Name: 56, dtype: object
# Unnamed: 0                                 57
# stop_id                                  3014
# route_short_name                           L4
# arrival_time                         12:47:00
# departure_time                       12:47:00
# trip_id             0004187292024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              3
# Name: 57, dtype: object
# Unnamed: 0                                 58
# stop_id                                  3094
# route_short_name                           L4
# arrival_time                         12:48:00
# departure_time                       12:48:00
# trip_id             0004187292024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              3
# Name: 58, dtype: object
# Unnamed: 0                                 59
# stop_id                                  3030
# route_short_name                           L4
# arrival_time                         12:52:00
# departure_time                       12:52:00
# trip_id             0004187292024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              4
# Name: 59, dtype: object
# Unnamed: 0                                 60
# stop_id                                  3031
# route_short_name                           L4
# arrival_time                         12:53:00
# departure_time                       12:53:00
# trip_id             0004187292024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              6
# Name: 60, dtype: object
# Unnamed: 0                                 61
# stop_id                                  3032
# route_short_name                           L4
# arrival_time                         12:54:00
# departure_time                       12:54:00
# trip_id             0004187292024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              0
# Name: 61, dtype: object
# Unnamed: 0                                 62
# stop_id                                  3033
# route_short_name                           L4
# arrival_time                         12:55:00
# departure_time                       12:55:00
# trip_id             0004187292024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              3
# Name: 62, dtype: object
# Unnamed: 0                                 63
# stop_id                                  3034
# route_short_name                           L4
# arrival_time                         12:56:00
# departure_time                       12:56:00
# trip_id             0004187292024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                  9
# passengers_out                              2
# Name: 63, dtype: object
# Unnamed: 0                                 64
# stop_id                                  3035
# route_short_name                           L4
# arrival_time                         12:57:00
# departure_time                       12:57:00
# trip_id             0004187292024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                  8
# passengers_out                              3
# Name: 64, dtype: object
# Unnamed: 0                                 65
# stop_id                                  3014
# route_short_name                           L4
# arrival_time                         13:00:00
# departure_time                       13:00:00
# trip_id             0004187292024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                  2
# passengers_out                              0
# Name: 65, dtype: object
# Unnamed: 0                                 66
# stop_id                                  3014
# route_short_name                           L4
# arrival_time                         18:03:00
# departure_time                       18:03:00
# trip_id             0004187302024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              4
# Name: 66, dtype: object
# Unnamed: 0                                 67
# stop_id                                  3094
# route_short_name                           L4
# arrival_time                         18:04:00
# departure_time                       18:04:00
# trip_id             0004187302024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 21
# passengers_out                              6
# Name: 67, dtype: object
# Unnamed: 0                                 68
# stop_id                                  3030
# route_short_name                           L4
# arrival_time                         18:08:00
# departure_time                       18:08:00
# trip_id             0004187302024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 22
# passengers_out                              6
# Name: 68, dtype: object
# Unnamed: 0                                 69
# stop_id                                  3031
# route_short_name                           L4
# arrival_time                         18:09:00
# departure_time                       18:09:00
# trip_id             0004187302024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 26
# passengers_out                              8
# Name: 69, dtype: object
# Unnamed: 0                                 70
# stop_id                                  3032
# route_short_name                           L4
# arrival_time                         18:10:00
# departure_time                       18:10:00
# trip_id             0004187302024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 15
# passengers_out                              4
# Name: 70, dtype: object
# Unnamed: 0                                 71
# stop_id                                  3033
# route_short_name                           L4
# arrival_time                         18:11:00
# departure_time                       18:11:00
# trip_id             0004187302024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                 10
# passengers_out                              2
# Name: 71, dtype: object
# Unnamed: 0                                 72
# stop_id                                  3034
# route_short_name                           L4
# arrival_time                         18:12:00
# departure_time                       18:12:00
# trip_id             0004187302024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              3
# Name: 72, dtype: object
# Unnamed: 0                                 73
# stop_id                                  3035
# route_short_name                           L4
# arrival_time                         18:13:00
# departure_time                       18:13:00
# trip_id             0004187302024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              9
# Name: 73, dtype: object
# Unnamed: 0                                 74
# stop_id                                  3014
# route_short_name                           L4
# arrival_time                         18:16:00
# departure_time                       18:16:00
# trip_id             0004187302024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              1
# Name: 74, dtype: object
# Unnamed: 0                                 75
# stop_id                                  3014
# route_short_name                           L1
# arrival_time                         07:38:00
# departure_time                       07:38:00
# trip_id             0004187312024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 22
# passengers_out                              4
# Name: 75, dtype: object
# Unnamed: 0                                 76
# stop_id                                  3016
# route_short_name                           L1
# arrival_time                         07:39:00
# departure_time                       07:39:00
# trip_id             0004187312024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              5
# Name: 76, dtype: object
# Unnamed: 0                                 77
# stop_id                                  3017
# route_short_name                           L1
# arrival_time                         07:40:00
# departure_time                       07:40:00
# trip_id             0004187312024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 21
# passengers_out                              4
# Name: 77, dtype: object
# Unnamed: 0                                 78
# stop_id                                  3018
# route_short_name                           L1
# arrival_time                         07:41:00
# departure_time                       07:41:00
# trip_id             0004187312024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 19
# passengers_out                              4
# Name: 78, dtype: object
# Unnamed: 0                                 79
# stop_id                                  3019
# route_short_name                           L1
# arrival_time                         07:43:00
# departure_time                       07:43:00
# trip_id             0004187312024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 15
# passengers_out                              4
# Name: 79, dtype: object
# Unnamed: 0                                 80
# stop_id                                  3079
# route_short_name                           L1
# arrival_time                         07:44:00
# departure_time                       07:44:00
# trip_id             0004187312024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                 25
# passengers_out                              8
# Name: 80, dtype: object
# Unnamed: 0                                 81
# stop_id                                  3040
# route_short_name                           L1
# arrival_time                         07:46:00
# departure_time                       07:46:00
# trip_id             0004187312024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              1
# Name: 81, dtype: object
# Unnamed: 0                                 82
# stop_id                                  3073
# route_short_name                           L1
# arrival_time                         07:46:00
# departure_time                       07:46:00
# trip_id             0004187312024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                 25
# passengers_out                              6
# Name: 82, dtype: object
# Unnamed: 0                                 83
# stop_id                                  3074
# route_short_name                           L1
# arrival_time                         07:47:00
# departure_time                       07:47:00
# trip_id             0004187312024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                 11
# passengers_out                              4
# Name: 83, dtype: object
# Unnamed: 0                                 84
# stop_id                                  3037
# route_short_name                           L1
# arrival_time                         07:49:00
# departure_time                       07:49:00
# trip_id             0004187312024090920250601
# stop_sequence                              10
# hospital                                    0
# school                                      0
# passengers                                 22
# passengers_out                              5
# Name: 84, dtype: object
# Unnamed: 0                                 85
# stop_id                                  3036
# route_short_name                           L1
# arrival_time                         07:49:00
# departure_time                       07:49:00
# trip_id             0004187312024090920250601
# stop_sequence                              11
# hospital                                    0
# school                                      0
# passengers                                 11
# passengers_out                              7
# Name: 85, dtype: object
# Unnamed: 0                                 86
# stop_id                                  3039
# route_short_name                           L1
# arrival_time                         07:49:00
# departure_time                       07:49:00
# trip_id             0004187312024090920250601
# stop_sequence                              12
# hospital                                    0
# school                                      0
# passengers                                 20
# passengers_out                              7
# Name: 86, dtype: object
# Unnamed: 0                                 87
# stop_id                                  3044
# route_short_name                           L1
# arrival_time                         07:50:00
# departure_time                       07:50:00
# trip_id             0004187312024090920250601
# stop_sequence                              13
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              4
# Name: 87, dtype: object
# Unnamed: 0                                 88
# stop_id                                  3085
# route_short_name                           L1
# arrival_time                         07:50:00
# departure_time                       07:50:00
# trip_id             0004187312024090920250601
# stop_sequence                              14
# hospital                                    0
# school                                      0
# passengers                                 22
# passengers_out                              5
# Name: 88, dtype: object
# Unnamed: 0                                 89
# stop_id                                  3080
# route_short_name                           L1
# arrival_time                         07:51:00
# departure_time                       07:51:00
# trip_id             0004187312024090920250601
# stop_sequence                              15
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              6
# Name: 89, dtype: object
# Unnamed: 0                                 90
# stop_id                                  3045
# route_short_name                           L1
# arrival_time                         07:52:00
# departure_time                       07:52:00
# trip_id             0004187312024090920250601
# ...
# trip_id             0004190952024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 12
# passengers_out                              4
# Name: 5013, dtype: object
# Unnamed: 0                               5014
# stop_id                                   165
# route_short_name                           10
# arrival_time                         16:36:00
# departure_time                       16:36:00
# trip_id             0004190952024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 25
# passengers_out                              7
# Name: 5014, dtype: object
# Unnamed: 0                               5015
# stop_id                                   166
# route_short_name                           10
# arrival_time                         16:38:00
# departure_time                       16:38:00
# trip_id             0004190952024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              8
# Name: 5015, dtype: object
# Unnamed: 0                               5016
# stop_id                                   177
# route_short_name                           10
# arrival_time                         16:40:00
# departure_time                       16:40:00
# trip_id             0004190952024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              4
# Name: 5016, dtype: object
# Unnamed: 0                               5017
# stop_id                                   306
# route_short_name                           10
# arrival_time                         16:42:00
# departure_time                       16:42:00
# trip_id             0004190952024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                 11
# passengers_out                              4
# Name: 5017, dtype: object
# Unnamed: 0                               5018
# stop_id                                   389
# route_short_name                           10
# arrival_time                         16:43:00
# departure_time                       16:43:00
# trip_id             0004190952024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                  9
# passengers_out                              4
# Name: 5018, dtype: object
# Unnamed: 0                               5019
# stop_id                                   388
# route_short_name                           10
# arrival_time                         16:43:00
# departure_time                       16:43:00
# trip_id             0004190952024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                 15
# passengers_out                              1
# Name: 5019, dtype: object
# Unnamed: 0                               5020
# stop_id                                   279
# route_short_name                           10
# arrival_time                         16:45:00
# departure_time                       16:45:00
# trip_id             0004190952024090920250601
# stop_sequence                              10
# hospital                                    0
# school                                      0
# passengers                                 26
# passengers_out                              6
# Name: 5020, dtype: object
# Unnamed: 0                               5021
# stop_id                                   327
# route_short_name                           10
# arrival_time                         16:46:00
# departure_time                       16:46:00
# trip_id             0004190952024090920250601
# stop_sequence                              11
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              0
# Name: 5021, dtype: object
# Unnamed: 0                               5022
# stop_id                                   308
# route_short_name                           10
# arrival_time                         16:47:00
# departure_time                       16:47:00
# trip_id             0004190952024090920250601
# stop_sequence                              12
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              3
# Name: 5022, dtype: object
# Unnamed: 0                               5023
# stop_id                                   103
# route_short_name                           10
# arrival_time                         16:48:00
# departure_time                       16:48:00
# trip_id             0004190952024090920250601
# stop_sequence                              13
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              4
# Name: 5023, dtype: object
# Unnamed: 0                               5024
# stop_id                                   106
# route_short_name                           10
# arrival_time                         16:49:00
# departure_time                       16:49:00
# trip_id             0004190952024090920250601
# stop_sequence                              14
# hospital                                    0
# school                                      0
# passengers                                 11
# passengers_out                              4
# Name: 5024, dtype: object
# Unnamed: 0                               5025
# stop_id                                   325
# route_short_name                           10
# arrival_time                         16:50:00
# departure_time                       16:50:00
# trip_id             0004190952024090920250601
# stop_sequence                              15
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              0
# Name: 5025, dtype: object
# Unnamed: 0                               5026
# stop_id                                   101
# route_short_name                           10
# arrival_time                         16:51:00
# departure_time                       16:51:00
# trip_id             0004190952024090920250601
# stop_sequence                              16
# hospital                                    0
# school                                      0
# passengers                                 15
# passengers_out                              5
# Name: 5026, dtype: object
# Unnamed: 0                               5027
# stop_id                                   104
# route_short_name                           10
# arrival_time                         16:52:00
# departure_time                       16:52:00
# trip_id             0004190952024090920250601
# stop_sequence                              17
# hospital                                    0
# school                                      0
# passengers                                  9
# passengers_out                              1
# Name: 5027, dtype: object
# Unnamed: 0                               5028
# stop_id                                   490
# route_short_name                           10
# arrival_time                         16:53:00
# departure_time                       16:53:00
# trip_id             0004190952024090920250601
# stop_sequence                              18
# hospital                                    0
# school                                      0
# passengers                                 22
# passengers_out                              6
# Name: 5028, dtype: object
# Unnamed: 0                               5029
# stop_id                                    21
# route_short_name                           10
# arrival_time                         16:55:00
# departure_time                       16:55:00
# trip_id             0004190952024090920250601
# stop_sequence                              19
# hospital                                    0
# school                                      0
# passengers                                 19
# passengers_out                              8
# Name: 5029, dtype: object
# Unnamed: 0                               5030
# stop_id                                   247
# route_short_name                           10
# arrival_time                         17:31:00
# departure_time                       17:31:00
# trip_id             0004190962024090920250601
# stop_sequence                               1
# hospital                                    0
# school                                      0
# passengers                                 13
# passengers_out                              4
# Name: 5030, dtype: object
# Unnamed: 0                               5031
# stop_id                                   407
# route_short_name                           10
# arrival_time                         17:33:00
# departure_time                       17:33:00
# trip_id             0004190962024090920250601
# stop_sequence                               2
# hospital                                    0
# school                                      0
# passengers                                 19
# passengers_out                              3
# Name: 5031, dtype: object
# Unnamed: 0                               5032
# stop_id                                   444
# route_short_name                           10
# arrival_time                         17:35:00
# departure_time                       17:35:00
# trip_id             0004190962024090920250601
# stop_sequence                               3
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              5
# Name: 5032, dtype: object
# Unnamed: 0                               5033
# stop_id                                   165
# route_short_name                           10
# arrival_time                         17:36:00
# departure_time                       17:36:00
# trip_id             0004190962024090920250601
# stop_sequence                               4
# hospital                                    0
# school                                      0
# passengers                                 20
# passengers_out                              7
# Name: 5033, dtype: object
# Unnamed: 0                               5034
# stop_id                                   166
# route_short_name                           10
# arrival_time                         17:38:00
# departure_time                       17:38:00
# trip_id             0004190962024090920250601
# stop_sequence                               5
# hospital                                    0
# school                                      0
# passengers                                 14
# passengers_out                              7
# Name: 5034, dtype: object
# Unnamed: 0                               5035
# stop_id                                   177
# route_short_name                           10
# arrival_time                         17:40:00
# departure_time                       17:40:00
# trip_id             0004190962024090920250601
# stop_sequence                               6
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              8
# Name: 5035, dtype: object
# Unnamed: 0                               5036
# stop_id                                   306
# route_short_name                           10
# arrival_time                         17:42:00
# departure_time                       17:42:00
# trip_id             0004190962024090920250601
# stop_sequence                               7
# hospital                                    0
# school                                      0
# passengers                                 18
# passengers_out                              4
# Name: 5036, dtype: object
# Unnamed: 0                               5037
# stop_id                                   389
# route_short_name                           10
# arrival_time                         17:43:00
# departure_time                       17:43:00
# trip_id             0004190962024090920250601
# stop_sequence                               8
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              0
# Name: 5037, dtype: object
# Unnamed: 0                               5038
# stop_id                                   388
# route_short_name                           10
# arrival_time                         17:43:00
# departure_time                       17:43:00
# trip_id             0004190962024090920250601
# stop_sequence                               9
# hospital                                    0
# school                                      0
# passengers                                 17
# passengers_out                              7
# Name: 5038, dtype: object
# Unnamed: 0                               5039
# stop_id                                   279
# route_short_name                           10
# arrival_time                         17:45:00
# departure_time                       17:45:00
# trip_id             0004190962024090920250601
# stop_sequence                              10
# hospital                                    0
# school                                      0
# passengers                                 16
# passengers_out                              3
# Name: 5039, dtype: object
# Unnamed: 0                               5040
# stop_id                                   327
# route_short_name                           10
# arrival_time                         17:46:00
# departure_time                       17:46:00
# trip_id             0004190962024090920250601
# stop_sequence                              11
# hospital                                    0
# school                                      0
# passengers                                 24
# passengers_out                              8
# Name: 5040, dtype: object
# Unnamed: 0                               5041
# stop_id                                   308
# route_short_name                           10
# arrival_time                         17:47:00
# departure_time                       17:47:00
# trip_id             0004190962024090920250601
# stop_sequence                              12
# hospital                                    0
# school                                      0
# passengers                                  7
# passengers_out                              0
# Name: 5041, dtype: object
# Unnamed: 0                               5042
# stop_id                                   103
# route_short_name                           10
# arrival_time                         17:48:00
# departure_time                       17:48:00
# trip_id             0004190962024090920250601
# stop_sequence                              13
# hospital                                    0
# school                                      0
# passengers                                 15
# passengers_out                              3
# Name: 5042, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 for _, x in df.iterrows():
# ----> 2     print(x)
#
# KeyboardInterrupt:

# %%
# pd.Series(df['stop_id'].unique(), name="stop_id").to_csv('../data/generated/stops.csv', index=False)

# %% [markdown]
# # Data Augmentation

# %%
df = pd.concat([df,df], axis = 0)

# %%
df = pd.concat([df,df], axis = 0)

# %%
df = pd.concat([df,df], axis = 0)

# %%
df = pd.concat([df,df], axis = 0)

# %%
df = pd.concat([df,df], axis = 0)

# %%
df = pd.concat([df,df], axis = 0)

# %%
len(df)
# Out:
# 28670400

# %% [markdown]
# # Data Preprocessing

# %%
df['departure_time'] = pd.to_timedelta(df['departure_time']).dt.total_seconds()
df['arrival_time'] = pd.to_timedelta(df['arrival_time']).dt.total_seconds()

# %%
df['time_sin'] = np.sin(2 * np.pi * df['arrival_time'] / 24)
# df['time_cos'] = np.cos(2 * np.pi * df['hours'] / 24)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['encoded_routes'] = le.fit_transform(df['route_short_name'])

print(df['encoded_routes'])
# Out:
# 0         26
# 1         26
# 2         26
# 3         26
# 4         26
#           ..
# 447970    23
# 447971    23
# 447972    23
# 447973    23
# 447974    23
# Name: encoded_routes, Length: 28670400, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = df[['arrival_time', 'stop_id', 'encoded_routes']]
# X = df['stop_id'].to_numpy().reshape(-1,1)
y = df['passengers']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# use below for model for passengers getting off the bus

# %%
from sklearn.model_selection import train_test_split

X = df[['arrival_time', 'stop_id', 'encoded_routes']]
# X = df['stop_id'].to_numpy().reshape(-1,1)
y = df['passengers_out']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Decision Tree
# Only works with the setup having arrival time and stop ID only since they don't need conversion to ordinal variables

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(X_test, y_test)
# Out:
# 0.38555051770756765

# %%
from pickle import dump
with open("../generate-passengers/treemodel_out.pkl", "wb") as f:
    dump(model, f, protocol=5)

# %%
# from pickle import dump
# with open("../generate-passengers/treemodel.pkl", "wb") as f:
#     dump(model, f, protocol=5)

# %%
X_test
# Out:
#         arrival_time  stop_id
# 417291       43560.0     2278
# 11255        58740.0      451
# 216423       73020.0      405
# 196991       41640.0      261
# 25429        28020.0      412
# ...              ...      ...
# 424556       42420.0     2302
# 214575       64080.0      407
# 52579        33120.0     1301
# 224383       43140.0      144
# 37860        23400.0      457
#
# [9461232 rows x 2 columns]

# %%
data_x = pd.DataFrame({'arrival_time' : [43560],
                       'stop_id' : [2278]})

# %%
np.round(model.predict(data_x))
# Out:
# array([12.])

# %%
# Out:
# 0         26
# 1         26
# 2         26
# 3         26
# 4         26
#           ..
# 447970    23
# 447971    23
# 447972    23
# 447973    23
# 447974    23
# Name: encoded_routes, Length: 447975, dtype: int64

# %%
le.transform(pd.Series("5"))
# Out:
# array([13])

# %%
le.inverse_transform(pd.Series(14))
# Out:
# array(['5/'], dtype=object)

# %%
le.inverse_transform(df['encoded_routes'])
# Out:
# array(['L1', 'L1', 'L1', ..., 'CM', 'CM', 'CM'],
#       shape=(28670400,), dtype=object)

# %%
from pickle import dump
with open("../generate-passengers/labelencoder.pkl", "wb") as f:
    dump(le, f, protocol=5)

# %%
X = df[['arrival_time', 'stop_id', 'encoded_routes']]
# X = df['stop_id'].to_numpy().reshape(-1,1)
y = df['passengers']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
tree = DecisionTreeRegressor()

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
le
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 le
#
# NameError: name 'le' is not defined

# %%
tree.score(X_test, y_test)
# Out:
# 0.5663461987355107

# %%
from pickle import dump
with open("../generate-passengers/treemodel.pkl", "wb") as f:
    dump(tree, f, protocol=5)

# %% [markdown]
# # Parquet file

# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/parquet/aggregated_df.parquet")

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['encoded_routes'] = le.fit_transform(df['route_short_name'])

# %%
X = df[['arrival_time', 'stop_id', 'encoded_routes']]
# X = df['stop_id'].to_numpy().reshape(-1,1)
y = df['passengers']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/UniTrento/Courses/Second Semester/BD/Technologies/BDTProject/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'passengers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 X = df[['arrival_time', 'stop_id', 'encoded_routes']]
#       2 # X = df['stop_id'].to_numpy().reshape(-1,1)
# ----> 3 y = df['passengers']
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
#
# File ~/Desktop/UniTrento/Courses/Second Semester/BD/Technologies/BDTProject/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Desktop/UniTrento/Courses/Second Semester/BD/Technologies/BDTProject/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'passengers'

# %%
tree = DecisionTreeRegressor()

# %%
tree.fit(X_train, y_train)
